# %%
#Q6) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
print(page)
from bs4 import BeautifulSoup
soup=BeautifulSoup(page.content)
Team=[]
for t in soup.find_all(class_="u-hide-phablet"):
    Team.append(t.text)
T=(Team[2:11])
T.insert(0,'Australia')
T

# %%
Match=[]
for m in soup.find_all(class_="table-body__cell u-center-text"):
    Match.append(m.text.split())
d=Match[0:17:2]
d.insert(0,20)
d

# %%
points=[]
for m in soup.find_all(class_="table-body__cell u-center-text"):
    points.append(m.text.split())
p=Match[1:18:2]
p.insert(0,3263)
p

# %%
len(T),len(p),len(d)

# %%
ranking=[]
for m in soup.find_all(class_="table-body__cell u-text-right rating"):
    ranking.append(m.text.split())


r=ranking[1:10]
r.insert(0,163)
r

# %%
len(T),len(p),len(d),len(r)

# %%
import pandas as pd
dg=pd.DataFrame({'Team':T,'Matches':d,'Points':p,'Ranking':r})
dg

# %%
#b)  Top 10 ODI women Batsmen along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests

# %%
pages=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')
pages

# %%
from bs4 import BeautifulSoup
soup1=BeautifulSoup(pages.content)
soup1

# %%
WBname=[]
for b in soup1.find_all(class_='table-body__cell name'):
    WBname.append(b.text.split())
WBname=(WBname[0:9])
WBname.insert(0,'Alyssa Healy')

print(WBname)

# %%
WBteam=[]
for t in soup1.find_all(class_='table-body__cell nationality-logo'):
        WBteam.append(t.text.split())
WBteam=(WBteam)[0:9]
WBteam.insert(0,'AUS')
print(WBteam)

# %%
WBrating=[]
for r in soup1.find_all(class_="table-body__cell u-text-right rating"):
    WBrating.append(r.text.split())
WBrating=(WBrating)[0:9]
WBrating.insert(0,749)
print(WBrating)

# %%
len(WBname),len(WBrating),len(WBteam)

# %%
import pandas as pd
WB=pd.DataFrame({'Player Name':WBname,'Team':WBteam,'Rating':WBrating})
print(WB)

# %%
WBname=[]
for b in soup1.find_all(class_='table-body__cell name'):
    WBname.append(b.text.split())
WBname=(WBname[18:27])
WBname.insert(0,'Ellyse Perry')

print(WBname)

# %%
WBteam=[]
for t in soup1.find_all(class_='table-body__cell nationality-logo'):
        WBteam.append(t.text.split())
WBteam=(WBteam)[18:27]
WBteam.insert(0,'AUS')
print(WBteam)

# %%
WBrating=[]
for r in soup1.find_all(class_="table-body__cell u-text-right rating"):
    WBrating.append(r.text.split())
WBrating=(WBrating)[18:27]
WBrating.insert(0,438)
print(WBrating)

# %%
import pandas as pd
WA=pd.DataFrame({'Player Name':WBname,'Team':WBteam,'Rating':WBrating})
print(WA)

# %% [markdown]
# #7) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content
# and the code for the video from the link for the youtube video from the post.

# %%
page=requests.get('https://coreyms.com/')
page

# %%
soup12=BeautifulSoup(page.content)
titles=[]
for h in soup12.find_all(class_="entry-title"):
    titles.append(h.text) 
print(titles)

# %%
dates=[]
for t in soup12.find_all(class_="entry-time"):
    dates.append(t.text) 
print(dates)

# %%
content=[]
for c in soup12.find_all(class_="entry-content"):
    content.append(c.text) 
print(content)

# %%
yt=['https://youtu.be/z0gguhEmWiY','https://youtu.be/_P7X8tMplsw','https://youtu.be/fKl2JW_qrso','https://youtu.be/IEEhzQoKtQU','https://youtu.be/mO_dS3rXDIs','none','https://youtu.be/2Fp1N6dof0Y','https://youtu.be/-nh9rCzPJ20','https://youtu.be/06I63_p-2A4','https://youtu.be/_JGmemuINww']

print(yt)
len(yt),len(dates),len(titles),len(content)

# %%
import pandas as pd
list=pd.DataFrame({'titles':titles,'date':dates,'content':content,'ytlink':yt})
list

# %% [markdown]
# #8) Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar

# %%
from bs4 import BeautifulSoup
import requests
page= requests.get('https://www.nobroker.in/property/sale/hyderabad/multiple?searchParam=&radius=2.0&city=hyderabad&locality=Jayanagar%20Colony,&locality=Indira%20Nagar')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
content=[]
for c in soup.find_all(class_="heading-6 flex items-center font-semi-bold m-0"):
    content.append(c.text.split())
print(content)
len((content))
# Out:
# [['3', 'BHK', 'Flat', 'For', 'Sale', 'In', 'Sigma', 'Central', 'Apartments', 'In', 'Serilingampalle'], ['2', 'BHK', 'Flat', 'For', 'Sale', 'In', 'Kumar', 'Residency', 'Kukatpally', 'In', 'Kukatpally'], ['2', 'BHK', 'Flat', 'For', 'Sale', 'In', 'Dwaraka', 'Sai', 'Residency', 'In', 'Chanda', 'Nagar'], ['2', 'BHK', 'Flat', 'For', 'Sale', 'In', 'Apartment', 'In', 'Chandanagar'], ['2', 'BHK', 'Flat', 'For', 'Sale', 'In', 'Sharada', 'Nilayam', 'In', 'Kukatpally']]
# 5

# %%
locality=[]
for l in soup.find_all(class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0 po:max-w-95"):
    locality.append(l.text)
print(locality)
len(locality)
# Out:
# ['Tara Nagar ', 'Jayanagar Colony, Sathavahana Nagar, Kukatpally, Hyderabad, Andra Pradesh, INDIA', 'Indira Nagar', 'Behind Venkateswara Swamy temple', 'nizampet main road ']
# 5

# %%
from bs4 import BeautifulSoup
import requests
page= requests.get('https://www.nobroker.in/property/sale/hyderabad/multiple?searchParam=&radius=2.0&city=hyderabad&locality=Jayanagar%20Colony,&locality=Indira%20Nagar')
page
soup=BeautifulSoup(page.content)

# %%
price=[]
for l in soup.find_all('div',class_="font-semi-bold heading-6"):
    price.append(l.text.split())
price=price[2:15:3]
print(price)
len(price)
# Out:
# [['₹77', 'Lacs'], ['₹73', 'Lacs'], ['₹35', 'Lacs'], ['₹45', 'Lacs'], ['₹40', 'Lacs']]
# 5

# %%
EMI=[]
for l in soup.find_all('div',class_="font-semi-bold heading-6"):
    EMI.append(l.text.replace('Month','').split())
EMI=EMI[1:15:3]
print(EMI)
len(EMI)
# Out:
# [['₹44,132/'], ['₹41,839/'], ['₹20,060/'], ['₹25,791/'], ['₹22,925/']]
# 5

# %%
import pandas as pd
list=pd.DataFrame({'content':content,'Locality':locality,'EMI/MONTH':EMI,'price in LAC':price})
list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-2f124ccf45d2> in <module>
# ----> 1 import pandas as pd
#       2 list=pd.DataFrame({'content':content,'Locality':locality,'EMI/MONTH':EMI,'price in LAC':price})
#       3 list
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in <module>
#     177
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     181
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_testing.py in <module>
#    3052
#    3053
# -> 3054 cython_table = pd.core.base.SelectionMixin._cython_table.items()
#    3055
#    3056
#
# ...

# %%
#Q9yt=['https://youtu.be/z0gguhEmWiY','https://youtu.be/_P7X8tMplsw','https://youtu.be/fKl2JW_qrso','https://youtu.be/IEEhzQoKtQU','https://youtu.be/mO_dS3rXDIs','none','https://youtu.be/2Fp1N6dof0Y','https://youtu.be/-nh9rCzPJ20','https://youtu.be/06I63_p-2A4','https://youtu.be/_JGmemuINww']

print(yt)
len(yt),len(dates),len(titles),len(content)
